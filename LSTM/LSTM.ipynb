# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/clean12345/clean.csv
# /kaggle/input/clean123/clean.csv

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
# 读取数据
df = pd.read_csv("/kaggle/input/clean12345/clean.csv")

# %%
# 划分训练集和测试集
train_df, test_df = train_test_split(df, test_size=0.3, random_state=42)

# 提取特征和标签
X_train = train_df.drop(columns=['price']).values
y_train = train_df['price'].values/1000000

X_test = test_df.drop(columns=['price']).values
y_test = test_df['price'].values/1000000

# 数据归一化
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 调整输入数据形状为 (samples, timesteps, features)
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# 构建 LSTM 模型
model = Sequential([
    LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu'),
    Dense(1)
])

# 编译模型
model.compile(optimizer='adam', loss='mean_squared_error')

# 训练模型
model.fit(X_train, y_train, epochs=200, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# 进行预测
predictions = model.predict(X_test)

# 计算均方误差
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 213.1559 - val_loss: 90.9291
# Epoch 2/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 83.6835 - val_loss: 67.4620
# Epoch 3/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 69.1961 - val_loss: 63.5186
# Epoch 4/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 65.9744 - val_loss: 60.3860
# Epoch 5/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 58.7142 - val_loss: 57.3058
# Epoch 6/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 59.2713 - val_loss: 54.7903
# Epoch 7/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 60.9899 - val_loss: 52.6538
# Epoch 8/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 55.8346 - val_loss: 50.7635
# Epoch 9/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 51.2915 - val_loss: 49.2478
# Epoch 10/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 50.5607 - val_loss: 47.9645
# Epoch 11/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 50.2696 - val_loss: 46.8103
# Epoch 12/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 54.0973 - val_loss: 46.3205
# Epoch 13/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 48.5491 - val_loss: 44.9494
# Epoch 14/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 46.8325 - val_loss: 44.3514
# Epoch 15/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 45.0400 - val_loss: 44.9871
# Epoch 16/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 47.3038 - val_loss: 43.4326
# Epoch 17/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 44.9781 - val_loss: 43.1890
# Epoch 18/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 44.0110 - val_loss: 42.2253
# Epoch 19/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 44.3238 - val_loss: 41.8545
# Epoch 20/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 43.5410 - val_loss: 41.3692
# Epoch 21/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 43.2185 - val_loss: 41.0868
# Epoch 22/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 43.1104 - val_loss: 40.6514
# Epoch 23/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 42.1733 - val_loss: 40.4073
# Epoch 24/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40.0557 - val_loss: 40.5582
# Epoch 25/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 43.6774 - val_loss: 39.9590
# Epoch 26/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42.7850 - val_loss: 40.0476
# Epoch 27/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 41.9748 - val_loss: 40.3273
# Epoch 28/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41.4740 - val_loss: 39.6412
# Epoch 29/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 39.2390 - val_loss: 39.0846
# Epoch 30/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 40.5721 - val_loss: 39.2240
# Epoch 31/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.5759 - val_loss: 38.7606
# Epoch 32/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 38.8230 - val_loss: 38.7447
# Epoch 33/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 40.1665 - val_loss: 38.4756
# Epoch 34/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 40.1044 - val_loss: 38.6950
# Epoch 35/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 40.3894 - val_loss: 38.4804
# Epoch 36/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.9737 - val_loss: 38.1655
# Epoch 37/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 39.5389 - val_loss: 37.9408
# Epoch 38/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 41.7306 - val_loss: 37.9486
# Epoch 39/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38.7369 - val_loss: 37.7206
# Epoch 40/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 39.0003 - val_loss: 38.1557
# Epoch 41/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 39.4631 - val_loss: 37.9640
# Epoch 42/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 39.3485 - val_loss: 37.6534
# Epoch 43/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 37.3825 - val_loss: 37.4571
# Epoch 44/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.2533 - val_loss: 37.9348
# Epoch 45/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39.7409 - val_loss: 37.2674
# Epoch 46/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 42.0124 - val_loss: 37.3776
# Epoch 47/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 39.5510 - val_loss: 37.6911
# Epoch 48/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.0699 - val_loss: 38.2660
# Epoch 49/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 38.3106 - val_loss: 37.7614
# Epoch 50/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.9906 - val_loss: 37.3454
# Epoch 51/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.9529 - val_loss: 38.2134
# Epoch 52/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 37.6873 - val_loss: 36.9481
# Epoch 53/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.3190 - val_loss: 36.8788
# Epoch 54/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 38.3231 - val_loss: 37.0065
# Epoch 55/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 38.4868 - val_loss: 37.2400
# Epoch 56/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.6091 - val_loss: 36.8189
# Epoch 57/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38.7239 - val_loss: 36.9485
# Epoch 58/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.6953 - val_loss: 36.7845
# Epoch 59/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36.8558 - val_loss: 36.8072
# Epoch 60/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.7081 - val_loss: 36.5242
# Epoch 61/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 40.6074 - val_loss: 36.4842
# Epoch 62/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.7041 - val_loss: 36.7072
# Epoch 63/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 38.3691 - val_loss: 39.3436
# Epoch 64/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 37.3966 - val_loss: 36.2543
# Epoch 65/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.8990 - val_loss: 36.3692
# Epoch 66/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36.2483 - val_loss: 36.2254
# Epoch 67/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.9586 - val_loss: 36.3199
# Epoch 68/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.8982 - val_loss: 36.2167
# Epoch 69/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.2114 - val_loss: 36.1370
# Epoch 70/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.4509 - val_loss: 36.0978
# Epoch 71/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36.9609 - val_loss: 36.1779
# Epoch 72/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.7926 - val_loss: 36.4721
# Epoch 73/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.6351 - val_loss: 36.0073
# Epoch 74/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.4923 - val_loss: 36.1640
# Epoch 75/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.4101 - val_loss: 35.8510
# Epoch 76/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 34.8408 - val_loss: 36.2234
# Epoch 77/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40.7258 - val_loss: 35.7507
# Epoch 78/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.4527 - val_loss: 35.9501
# Epoch 79/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.8709 - val_loss: 35.6618
# Epoch 80/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.5972 - val_loss: 35.7952
# Epoch 81/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.7805 - val_loss: 35.6550
# Epoch 82/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 35.6060 - val_loss: 35.6114
# Epoch 83/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.4007 - val_loss: 35.7387
# Epoch 84/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38.6226 - val_loss: 36.0016
# Epoch 85/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.2287 - val_loss: 35.7517
# Epoch 86/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.0247 - val_loss: 35.8846
# Epoch 87/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36.3967 - val_loss: 35.7379
# Epoch 88/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 38.6581 - val_loss: 35.7559
# Epoch 89/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.2491 - val_loss: 35.4768
# Epoch 90/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.8281 - val_loss: 35.5563
# Epoch 91/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 37.3090 - val_loss: 35.3806
# Epoch 92/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 35.4631 - val_loss: 35.8836
# Epoch 93/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 34.6031 - val_loss: 35.6418
# Epoch 94/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38.3410 - val_loss: 35.8772
# Epoch 95/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.7354 - val_loss: 37.4581
# Epoch 96/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.9748 - val_loss: 35.4579
# Epoch 97/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.9022 - val_loss: 35.2847
# Epoch 98/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.2105 - val_loss: 35.3799
# Epoch 99/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39.5534 - val_loss: 35.2380
# Epoch 100/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.9196 - val_loss: 35.1746
# Epoch 101/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34.9664 - val_loss: 35.2308
# Epoch 102/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.3252 - val_loss: 36.7718
# Epoch 103/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 37.1361 - val_loss: 35.1357
# Epoch 104/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.3069 - val_loss: 35.3234
# Epoch 105/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.9621 - val_loss: 35.2545
# Epoch 106/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 35.2141 - val_loss: 35.1760
# Epoch 107/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 37.6868 - val_loss: 35.1429
# Epoch 108/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36.3033 - val_loss: 35.1099
# Epoch 109/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.9549 - val_loss: 35.2777
# Epoch 110/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.9993 - val_loss: 35.4458
# Epoch 111/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.6866 - val_loss: 35.2863
# Epoch 112/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 36.4010 - val_loss: 35.3058
# Epoch 113/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.6032 - val_loss: 35.0878
# Epoch 114/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.9547 - val_loss: 34.9186
# Epoch 115/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.4760 - val_loss: 35.0115
# Epoch 116/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.2322 - val_loss: 34.9779
# Epoch 117/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.8900 - val_loss: 35.2741
# Epoch 118/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.8011 - val_loss: 35.1880
# Epoch 119/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.3925 - val_loss: 35.2501
# Epoch 120/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.1982 - val_loss: 35.5150
# Epoch 121/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 36.4581 - val_loss: 35.3629
# Epoch 122/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.0544 - val_loss: 35.0322
# Epoch 123/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.3231 - val_loss: 36.3387
# Epoch 124/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.2931 - val_loss: 35.3466
# Epoch 125/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 33.1634 - val_loss: 34.8708
# Epoch 126/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.4128 - val_loss: 34.8120
# Epoch 127/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.6205 - val_loss: 35.8364
# Epoch 128/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.8908 - val_loss: 35.0014
# Epoch 129/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.6809 - val_loss: 35.7566
# Epoch 130/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.1798 - val_loss: 35.0936
# Epoch 131/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.2179 - val_loss: 34.7550
# Epoch 132/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.1478 - val_loss: 35.0984
# Epoch 133/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 39.0555 - val_loss: 35.0775
# Epoch 134/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.7618 - val_loss: 34.9042
# Epoch 135/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.8594 - val_loss: 34.6899
# Epoch 136/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.4199 - val_loss: 35.0330
# Epoch 137/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.2557 - val_loss: 35.1493
# Epoch 138/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.0826 - val_loss: 34.7113
# Epoch 139/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.0466 - val_loss: 34.8424
# Epoch 140/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.7674 - val_loss: 34.7694
# Epoch 141/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36.3596 - val_loss: 36.8007
# Epoch 142/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.8532 - val_loss: 34.6098
# Epoch 143/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.1995 - val_loss: 35.7423
# Epoch 144/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 31.5922 - val_loss: 34.6881
# Epoch 145/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.7884 - val_loss: 34.9877
# Epoch 146/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.4858 - val_loss: 35.1537
# Epoch 147/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.4561 - val_loss: 34.8958
# Epoch 148/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.8439 - val_loss: 34.9756
# Epoch 149/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.2735 - val_loss: 34.9756
# Epoch 150/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32.1113 - val_loss: 34.4440
# Epoch 151/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.7673 - val_loss: 34.8531
# Epoch 152/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.6528 - val_loss: 34.4493
# Epoch 153/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 36.3367 - val_loss: 34.5463
# Epoch 154/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.6190 - val_loss: 34.5511
# Epoch 155/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.6155 - val_loss: 34.4973
# Epoch 156/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34.4825 - val_loss: 34.3786
# Epoch 157/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.3473 - val_loss: 34.3957
# Epoch 158/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.3553 - val_loss: 37.4547
# Epoch 159/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 35.3532 - val_loss: 34.4688
# Epoch 160/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 31.7244 - val_loss: 34.4391
# Epoch 161/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.4971 - val_loss: 35.2019
# Epoch 162/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 30.8370 - val_loss: 34.3531
# Epoch 163/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.1474 - val_loss: 34.4195
# Epoch 164/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 30.3650 - val_loss: 34.4168
# Epoch 165/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.2428 - val_loss: 34.3383
# Epoch 166/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.5949 - val_loss: 34.2981
# Epoch 167/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 34.0311 - val_loss: 34.5610
# Epoch 168/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.1069 - val_loss: 36.5290
# Epoch 169/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.2816 - val_loss: 34.2505
# Epoch 170/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.3123 - val_loss: 37.5647
# Epoch 171/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 34.6005 - val_loss: 34.2674
# Epoch 172/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 32.0980 - val_loss: 34.4936
# Epoch 173/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 32.7048 - val_loss: 37.0939
# Epoch 174/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.9478 - val_loss: 34.5557
# Epoch 175/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.6794 - val_loss: 34.2867
# Epoch 176/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.8554 - val_loss: 34.5854
# Epoch 177/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.9057 - val_loss: 34.2571
# Epoch 178/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.5086 - val_loss: 34.2849
# Epoch 179/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.2010 - val_loss: 34.4393
# Epoch 180/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.8468 - val_loss: 35.1731
# Epoch 181/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.6932 - val_loss: 34.4658
# Epoch 182/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35.1767 - val_loss: 34.1821
# Epoch 183/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 30.6254 - val_loss: 34.1276
# Epoch 184/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 34.5366 - val_loss: 34.4105
# Epoch 185/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 32.0289 - val_loss: 34.1973
# Epoch 186/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.4463 - val_loss: 34.6803
# Epoch 187/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.9541 - val_loss: 34.0109
# Epoch 188/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.5802 - val_loss: 34.2671
# Epoch 189/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.9003 - val_loss: 34.0723
# Epoch 190/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.1463 - val_loss: 34.2412
# Epoch 191/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.3244 - val_loss: 34.0853
# Epoch 192/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 30.7515 - val_loss: 34.5833
# Epoch 193/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.6106 - val_loss: 34.2716
# Epoch 194/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 31.2320 - val_loss: 33.9562
# Epoch 195/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 30.2723 - val_loss: 34.9019
# Epoch 196/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 33.7769 - val_loss: 33.9702
# Epoch 197/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 31.1285 - val_loss: 34.6032
# Epoch 198/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.4309 - val_loss: 34.1626
# Epoch 199/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 30.8487 - val_loss: 34.1326
# Epoch 200/200
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 32.6501 - val_loss: 34.5967
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step
# Mean Squared Error: 34.58916617248221
